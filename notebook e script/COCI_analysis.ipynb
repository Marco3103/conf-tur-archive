# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

plt.style.use('seaborn-colorblind')

# %% [markdown]
# - Vedo se trovo qualche caso particolare di andamenti di citazioni, come nelle fig. 1 e 2 del paper.
# - Nei dati nuovi, ho due classi di ranking: CORE e GRIN.
# Per CORE abbiamo i rating di diversi anni: 20xx, 20xx ecc. Andrò quindi ad osservare le citazioni negli anni per i quali ho il rating.
# Per quanto riguarda GRIN, abbiamo soltanto la classe e il rating aggiornati al 24/10/2021 (quindi un solo valore per ogni conferenza): di conseguenza guarderò l'andamento delle citazioni di tutti gli anni (a differenza di CORE)

# %%
df_COCI = pd.read_csv('out_COCI_citations_and_locations_analysis_ready.csv', index_col='ConferenceSeriesNormalizedName')
df_COCI.drop(columns='Unnamed: 0', inplace=True)
df_COCI
# Out:
#                                 CitationCount  \
# ConferenceSeriesNormalizedName
# disc                                       10
# esa                                         5
# enter                                      11
# dexa                                        1
# icaisc                                      9
# ...                                       ...
# sapere                                      4
# sapere                                      4
# sapere                                      2
# sapere                                      0
# sapere                                      3
#
#                                                                ConferenceLocation  \
# ConferenceSeriesNormalizedName
# disc                                                 Austin, Texas, United States
# esa                                   Wrocław, Lower Silesian Voivodeship, Poland
# enter                                                   Innsbruck, Tyrol, Austria
# dexa                            Villefranche-sur-Saône, Auvergne-Rhône-Alpes, ...
# icaisc                                Zakopane, Lesser Poland Voivodeship, Poland
# ...                                                                           ...
# sapere                                 Thessaloniki, Macedonia and Thrace, Greece
# sapere                                 Thessaloniki, Macedonia and Thrace, Greece
# sapere                                 Thessaloniki, Macedonia and Thrace, Greece
# sapere                                 Thessaloniki, Macedonia and Thrace, Greece
# sapere                                 Thessaloniki, Macedonia and Thrace, Greece
#
#                                ConferenceNormalizedName  \
# ConferenceSeriesNormalizedName
# disc                                          disc 2014
# esa                                            esa 2014
# enter                                        enter 2013
# dexa                                          dexa 2002
# icaisc                                      icaisc 2006
# ...                                                 ...
# sapere                                      sapere 2011
# sapere                                      sapere 2011
# sapere                                      sapere 2011
# sapere                                      sapere 2011
# sapere                                      sapere 2011
#
#                                                          Doi  Year
# ConferenceSeriesNormalizedName
# disc                            10.1007/978-3-662-45174-8_28  2014
# esa                             10.1007/978-3-662-44777-2_60  2014
# enter                           10.1007/978-3-319-03973-2_13  2013
# dexa                                10.1007/3-540-46146-9_77  2002
# icaisc                                   10.1007/11785231_94  2006
# ...                                                      ...   ...
# sapere                           10.1007/978-3-642-31674-6_9  2011
# sapere                          10.1007/978-3-642-31674-6_20  2011
# sapere                          10.1007/978-3-642-31674-6_25  2011
# sapere                          10.1007/978-3-642-31674-6_12  2011
# sapere                           10.1007/978-3-642-31674-6_3  2011
#
# [3107883 rows x 5 columns]

# %%
tot_cit_year = df_COCI.groupby(['ConferenceSeriesNormalizedName', 'Year']).CitationCount.sum().sort_values(ascending=False)
tot_articles_year = df_COCI.groupby(['ConferenceSeriesNormalizedName', 'Year']).CitationCount.count()

# creo un dataframe dove per ogni conferenza seguo l'evoluzione annuale solo delle citazioni medie 
lst_dataframes = []
keys = df_COCI.groupby(['ConferenceSeriesNormalizedName']).CitationCount.count().keys()

for conference in keys:
    single_conference = {}
    n_editions = 0
    for k,v in tot_cit_year[conference].items():
        single_conference[str(k)] = v/tot_articles_year[conference][k] #calcolo citazioni medie per ogni anno
        n_editions +=1
    if n_editions>1:
        lst_dataframes.append(pd.DataFrame(data=[single_conference.values()], index = [conference], columns=single_conference.keys()))
# unisco tutti i dataframe creati
avg_cit_per_year = pd.concat(lst_dataframes)
avg_cit_per_year = avg_cit_per_year.reindex(sorted(avg_cit_per_year.columns), axis=1)

avg_cit_per_year.head(10)
# Out:
#           1951  1952  1953  1954  1955  1956  1957  1958  1959  1960  ...  \
# 3dic       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dica      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dim       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dimpvt    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dor       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dpvt      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dtv       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dtv-con   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dui       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dv        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                2013      2014      2015      2016      2017      2018  \
# 3dic       0.000000       NaN       NaN  1.333333       NaN       NaN
# 3dica      1.161290  0.466667  0.520000       NaN       NaN       NaN
# 3dim            NaN       NaN       NaN       NaN  2.000000  1.000000
# 3dimpvt         NaN       NaN       NaN       NaN       NaN       NaN
# 3dor            NaN       NaN       NaN  0.000000  0.500000       NaN
# 3dpvt           NaN       NaN       NaN       NaN       NaN       NaN
# 3dtv            NaN  0.000000  0.000000  0.000000       NaN       NaN
# 3dtv-con        NaN  2.551724  2.642857  1.625000  1.419355       NaN
# 3dui       5.312500  7.836364  4.339286  6.034483  5.014925       NaN
# 3dv       17.357143  5.122642  5.256757       NaN  9.410959  5.345679
#
#               2019      2020  2021  2022
# 3dic           NaN       NaN   0.0   NaN
# 3dica          NaN  0.333333   NaN   NaN
# 3dim      2.000000       NaN   0.0   NaN
# 3dimpvt        NaN       NaN   NaN   NaN
# 3dor           NaN  0.166667   NaN   NaN
# 3dpvt          NaN       NaN   NaN   NaN
# 3dtv           NaN       NaN   NaN   NaN
# 3dtv-con       NaN       NaN   NaN   NaN
# 3dui           NaN       NaN   NaN   NaN
# 3dv       2.538462       NaN   NaN   NaN
#
# [10 rows x 72 columns]

# %%
# stessa cosa ma per le citazioni totali
lst_dataframes = []
for conference in keys:
    single_conference = {}
    n_editions = 0
    for k,v in tot_cit_year[conference].items():
        single_conference[str(k)] = v 
        n_editions += 1
    if n_editions >1:
        lst_dataframes.append(pd.DataFrame(data=[single_conference.values()], index = [conference], columns=single_conference.keys()))

tot_cit_per_year = pd.concat(lst_dataframes)
tot_cit_per_year = tot_cit_per_year.reindex(sorted(tot_cit_per_year.columns), axis=1)
tot_cit_per_year.head(10)
# Out:
#           1951  1952  1953  1954  1955  1956  1957  1958  1959  1960  ...  \
# 3dic       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dica      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dim       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dimpvt    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dor       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dpvt      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dtv       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dtv-con   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dui       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3dv        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#            2013   2014   2015   2016   2017   2018   2019  2020  2021  2022
# 3dic        0.0    NaN    NaN    4.0    NaN    NaN    NaN   NaN   0.0   NaN
# 3dica      36.0    7.0   13.0    NaN    NaN    NaN    NaN   2.0   NaN   NaN
# 3dim        NaN    NaN    NaN    NaN    2.0    2.0    2.0   NaN   0.0   NaN
# 3dimpvt     NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 3dor        NaN    NaN    NaN    0.0    1.0    NaN    NaN   1.0   NaN   NaN
# 3dpvt       NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 3dtv        NaN    0.0    0.0    0.0    NaN    NaN    NaN   NaN   NaN   NaN
# 3dtv-con    NaN  148.0   74.0   39.0   44.0    NaN    NaN   NaN   NaN   NaN
# 3dui      340.0  431.0  243.0  350.0  336.0    NaN    NaN   NaN   NaN   NaN
# 3dv       972.0  543.0  389.0    NaN  687.0  433.0  198.0   NaN   NaN   NaN
#
# [10 rows x 72 columns]

# %% [markdown]
# ### Andamento delle citazioni totali per il ranking CORE
# Abbiamo il ranking per gli anni 2008,2013,2014,2017,2018,2020,2021
# Estraggo quindi le citazioni di questi anni e le raccolgo in un dataframe.
# Dopodichè analizzerò le conferenze per le quali la classe rimane invariata nei vari anni disponibili

# %%
ranking_core = pd.read_csv('out_conference_series_with_core_rank.csv', index_col='ConferenceSeriesNormalizedName')
ranking_core.drop(columns='Unnamed: 0', inplace=True)
# mantengo le righe per le quali ho lo stesso ranking per ogni anno
ranking_core.dropna(how='any', inplace=True) 
ranking_core = ranking_core[ranking_core.eq(ranking_core.iloc[:, 0], axis=0).all(1)]

ranking_core
# Out:
#                                CORE_2008_Rank CORE_2013_Rank CORE_2014_Rank  \
# ConferenceSeriesNormalizedName
# disc                                        A              A              A
# esa                                         A              A              A
# safecomp                                    B              B              B
# kes                                         B              B              B
# seal                                        B              B              B
# ...                                       ...            ...            ...
# lpar                                        A              A              A
# seta                                        B              B              B
# sirocco                                     B              B              B
# pacling                                     B              B              B
# hotos                                       A              A              A
#
#                                CORE_2017_Rank CORE_2018_Rank CORE_2020_Rank  \
# ConferenceSeriesNormalizedName
# disc                                        A              A              A
# esa                                         A              A              A
# safecomp                                    B              B              B
# kes                                         B              B              B
# seal                                        B              B              B
# ...                                       ...            ...            ...
# lpar                                        A              A              A
# seta                                        B              B              B
# sirocco                                     B              B              B
# pacling                                     B              B              B
# hotos                                       A              A              A
#
#                                CORE_2021_Rank ERA_2010_Rank
# ConferenceSeriesNormalizedName
# disc                                        A             A
# esa                                         A             A
# safecomp                                    B             B
# kes                                         B             B
# seal                                        B             B
# ...                                       ...           ...
# lpar                                        A             A
# seta                                        B             B
# sirocco                                     B             B
# pacling                                     B             B
# hotos                                       A             A
#
# [187 rows x 8 columns]

# %%
# join cit totali e ranking

tot_cit_core = ranking_core.join(tot_cit_per_year)
# conservo solo le citazioni degli anni per i quali ho il ranking CORE
columns_to_drop = list(range(1951,2008)) + [2009,2010,2011,2012,2015,2016,2019,2022]
columns_to_drop = [str(x) for x in columns_to_drop] + ['ERA_2010_Rank']
tot_cit_core.drop(columns=columns_to_drop, inplace=True)
# elimino le conferenze per le quali non ho citazioni in quegli anni
tot_cit_core.dropna(subset=['2008','2013','2014','2017','2018','2020','2021'], inplace=True)

tot_cit_core
# Out:
#                                CORE_2008_Rank CORE_2013_Rank CORE_2014_Rank  \
# ConferenceSeriesNormalizedName
# ideal                                       C              C              C
# iccsa                                       C              C              C
# ecoop                                       A              A              A
# parco                                       C              C              C
# opodis                                      B              B              B
# ipco                                        A              A              A
# ace                                         B              B              B
# vtc                                         B              B              B
# gd                                          A              A              A
# bibe                                        C              C              C
# lopstr                                      B              B              B
# aina                                        B              B              B
# compsac                                     B              B              B
# cocoa                                       B              B              B
# wacv                                        A              A              A
# wcnc                                        B              B              B
# pimrc                                       B              B              B
# ccgrid                                      A              A              A
# iccad                                       A              A              A
# ppopp                                       A              A              A
# icce                                        B              B              B
# igarss                                      C              C              C
# tencon                                      C              C              C
# spire                                       B              B              B
# edbt                                        A              A              A
# cgo                                         A              A              A
# iccs                                        A              A              A
# ipccc                                       B              B              B
# fmics                                       C              C              C
# sc                                          A              A              A
# iwcmc                                       B              B              B
# issre                                       A              A              A
# caise                                       A              A              A
# bpm                                         A              A              A
# rtas                                        A              A              A
# icnp                                        A              A              A
# mswim                                       A              A              A
# esorics                                     A              A              A
# prima                                       B              B              B
# adbis                                       B              B              B
# esem                                        A              A              A
# fase                                        B              B              B
# refsq                                       B              B              B
# rtcsa                                       B              B              B
# middleware                                  A              A              A
#
#                                CORE_2017_Rank CORE_2018_Rank CORE_2020_Rank  \
# ConferenceSeriesNormalizedName
# ideal                                       C              C              C
# iccsa                                       C              C              C
# ecoop                                       A              A              A
# parco                                       C              C              C
# opodis                                      B              B              B
# ipco                                        A              A              A
# ace                                         B              B              B
# vtc                                         B              B              B
# gd                                          A              A              A
# bibe                                        C              C              C
# lopstr                                      B              B              B
# aina                                        B              B              B
# compsac                                     B              B              B
# cocoa                                       B              B              B
# wacv                                        A              A              A
# wcnc                                        B              B              B
# pimrc                                       B              B              B
# ccgrid                                      A              A              A
# iccad                                       A              A              A
# ppopp                                       A              A              A
# icce                                        B              B              B
# igarss                                      C              C              C
# tencon                                      C              C              C
# spire                                       B              B              B
# edbt                                        A              A              A
# cgo                                         A              A              A
# iccs                                        A              A              A
# ipccc                                       B              B              B
# fmics                                       C              C              C
# sc                                          A              A              A
# iwcmc                                       B              B              B
# issre                                       A              A              A
# caise                                       A              A              A
# bpm                                         A              A              A
# rtas                                        A              A              A
# icnp                                        A              A              A
# mswim                                       A              A              A
# esorics                                     A              A              A
# prima                                       B              B              B
# adbis                                       B              B              B
# esem                                        A              A              A
# fase                                        B              B              B
# refsq                                       B              B              B
# rtcsa                                       B              B              B
# middleware                                  A              A              A
#
#                                CORE_2021_Rank    2008    2013    2014    2017  \
# ConferenceSeriesNormalizedName
# ideal                                       C   223.0   290.0   171.0    87.0
# iccsa                                       C   906.0   978.0  1016.0   773.0
# ecoop                                       A   603.0   688.0   455.0    56.0
# parco                                       C   755.0   837.0   653.0   454.0
# opodis                                      B   322.0   133.0   148.0     7.0
# ipco                                        A   289.0     0.0    99.0   140.0
# ace                                         B   602.0   273.0     0.0   183.0
# vtc                                         B  6360.0  4547.0  3032.0  1264.0
# gd                                          A     1.0   185.0   133.0    82.0
# bibe                                        C   544.0   511.0    17.0   143.0
# lopstr                                      B    65.0    32.0    29.0    59.0
# aina                                        B  1845.0  1953.0  1501.0   745.0
# compsac                                     B   952.0   951.0   757.0   565.0
# cocoa                                       B   137.0    53.0   114.0    81.0
# wacv                                        A   485.0  1056.0  1176.0  1287.0
# wcnc                                        B  3821.0  3380.0  2660.0  1208.0
# pimrc                                       B  3497.0  3087.0  1336.0   851.0
# ccgrid                                      A   965.0   991.0   842.0   723.0
# iccad                                       A  1044.0  1443.0   899.0   585.0
# ppopp                                       A  1440.0  1254.0  1127.0   381.0
# icce                                        B   607.0   943.0  1713.0   707.0
# igarss                                      C  3375.0  1605.0  1849.0  1379.0
# tencon                                      C  1531.0   805.0   369.0   556.0
# spire                                       B   151.0   145.0    55.0    66.0
# edbt                                        A   184.0  1139.0    11.0    27.0
# cgo                                         A   512.0   428.0     9.0     7.0
# iccs                                        A  1625.0  2470.0  2444.0  1097.0
# ipccc                                       B   327.0   141.0   260.0   151.0
# fmics                                       C     0.0    59.0    68.0    37.0
# sc                                          A   446.0   148.0   484.0    17.0
# iwcmc                                       B   859.0  1351.0   698.0     1.0
# issre                                       A   509.0     0.0   687.0   160.0
# caise                                       A    70.0   676.0   760.0   417.0
# bpm                                         A  1614.0  1129.0   616.0   470.0
# rtas                                        A   788.0   394.0   449.0   139.0
# icnp                                        A   309.0   770.0   659.0   194.0
# mswim                                       A   447.0   348.0   154.0   128.0
# esorics                                     A   731.0   833.0  1025.0   660.0
# prima                                       B   136.0   197.0    73.0    69.0
# adbis                                       B    52.0   138.0   158.0   113.0
# esem                                        A   942.0   677.0   534.0     6.0
# fase                                        B   420.0   396.0   236.0   166.0
# refsq                                       B   189.0   204.0   147.0   129.0
# rtcsa                                       B   412.0   185.0   191.0    72.0
# middleware                                  A   755.0   245.0   435.0   265.0
#
#                                   2018   2020   2021
# ConferenceSeriesNormalizedName
# ideal                            156.0   26.0    0.0
# iccsa                            526.0  384.0   27.0
# ecoop                             34.0   26.0    5.0
# parco                            232.0   83.0   15.0
# opodis                            14.0    5.0    0.0
# ipco                               1.0   59.0   10.0
# ace                               71.0   34.0    5.0
# vtc                              714.0    4.0   33.0
# gd                                68.0   38.0    2.0
# bibe                              57.0   46.0    1.0
# lopstr                            14.0    9.0    0.0
# aina                             471.0  177.0   31.0
# compsac                          519.0   81.0   17.0
# cocoa                             35.0   22.0    5.0
# wacv                            1541.0  762.0  235.0
# wcnc                             813.0  169.0   35.0
# pimrc                            298.0   71.0    2.0
# ccgrid                           154.0   77.0    5.0
# iccad                            457.0    0.0    0.0
# ppopp                            377.0   92.0   25.0
# icce                             735.0  152.0   30.0
# igarss                          1379.0  124.0   23.0
# tencon                           318.0   46.0    0.0
# spire                             36.0    9.0    0.0
# edbt                              18.0    6.0    1.0
# cgo                               58.0   49.0    9.0
# iccs                             618.0  302.0   67.0
# ipccc                             68.0    7.0    0.0
# fmics                             60.0   19.0    1.0
# sc                               140.0   44.0    6.0
# iwcmc                            401.0   71.0    6.0
# issre                            170.0   45.0    0.0
# caise                            316.0  154.0   14.0
# bpm                              368.0  153.0    5.0
# rtas                              80.0   18.0    3.0
# icnp                              88.0   17.0    0.0
# mswim                            100.0   45.0    1.0
# esorics                          336.0  107.0    0.0
# prima                             70.0    3.0    0.0
# adbis                             69.0   56.0    1.0
# esem                             211.0   33.0    6.0
# fase                             103.0   80.0   14.0
# refsq                             53.0   23.0    2.0
# rtcsa                             56.0    3.0    1.0
# middleware                       152.0   38.0    1.0

# %% [markdown]
# #### Ora da qui prendo i casi più interessanti di variazioni di citazioni.
# #### Le colonne dei ranking sono superflue (sono tutte uguali) quindi ne lascio soltanto una

# %%
tot_cit_core.drop(columns=['CORE_2013_Rank','CORE_2014_Rank', 'CORE_2017_Rank','CORE_2018_Rank','CORE_2020_Rank','CORE_2021_Rank'], inplace=True)
tot_cit_core.rename(columns={'CORE_2008_Rank' : 'Rank'}, inplace=True)
tot_cit_core.sort_values(by=['Rank'], inplace=True)
tot_cit_core
# Out:
#                                Rank    2008    2013    2014    2017    2018  \
# ConferenceSeriesNormalizedName
# middleware                        A   755.0   245.0   435.0   265.0   152.0
# icnp                              A   309.0   770.0   659.0   194.0    88.0
# rtas                              A   788.0   394.0   449.0   139.0    80.0
# bpm                               A  1614.0  1129.0   616.0   470.0   368.0
# caise                             A    70.0   676.0   760.0   417.0   316.0
# issre                             A   509.0     0.0   687.0   160.0   170.0
# sc                                A   446.0   148.0   484.0    17.0   140.0
# iccs                              A  1625.0  2470.0  2444.0  1097.0   618.0
# cgo                               A   512.0   428.0     9.0     7.0    58.0
# edbt                              A   184.0  1139.0    11.0    27.0    18.0
# ppopp                             A  1440.0  1254.0  1127.0   381.0   377.0
# mswim                             A   447.0   348.0   154.0   128.0   100.0
# ccgrid                            A   965.0   991.0   842.0   723.0   154.0
# wacv                              A   485.0  1056.0  1176.0  1287.0  1541.0
# iccad                             A  1044.0  1443.0   899.0   585.0   457.0
# esorics                           A   731.0   833.0  1025.0   660.0   336.0
# ecoop                             A   603.0   688.0   455.0    56.0    34.0
# ipco                              A   289.0     0.0    99.0   140.0     1.0
# esem                              A   942.0   677.0   534.0     6.0   211.0
# gd                                A     1.0   185.0   133.0    82.0    68.0
# refsq                             B   189.0   204.0   147.0   129.0    53.0
# fase                              B   420.0   396.0   236.0   166.0   103.0
# opodis                            B   322.0   133.0   148.0     7.0    14.0
# iwcmc                             B   859.0  1351.0   698.0     1.0   401.0
# ace                               B   602.0   273.0     0.0   183.0    71.0
# prima                             B   136.0   197.0    73.0    69.0    70.0
# ipccc                             B   327.0   141.0   260.0   151.0    68.0
# wcnc                              B  3821.0  3380.0  2660.0  1208.0   813.0
# spire                             B   151.0   145.0    55.0    66.0    36.0
# rtcsa                             B   412.0   185.0   191.0    72.0    56.0
# adbis                             B    52.0   138.0   158.0   113.0    69.0
# icce                              B   607.0   943.0  1713.0   707.0   735.0
# lopstr                            B    65.0    32.0    29.0    59.0    14.0
# aina                              B  1845.0  1953.0  1501.0   745.0   471.0
# compsac                           B   952.0   951.0   757.0   565.0   519.0
# pimrc                             B  3497.0  3087.0  1336.0   851.0   298.0
# cocoa                             B   137.0    53.0   114.0    81.0    35.0
# vtc                               B  6360.0  4547.0  3032.0  1264.0   714.0
# ideal                             C   223.0   290.0   171.0    87.0   156.0
# igarss                            C  3375.0  1605.0  1849.0  1379.0  1379.0
# bibe                              C   544.0   511.0    17.0   143.0    57.0
# parco                             C   755.0   837.0   653.0   454.0   232.0
# iccsa                             C   906.0   978.0  1016.0   773.0   526.0
# fmics                             C     0.0    59.0    68.0    37.0    60.0
# tencon                            C  1531.0   805.0   369.0   556.0   318.0
#
#                                  2020   2021
# ConferenceSeriesNormalizedName
# middleware                       38.0    1.0
# icnp                             17.0    0.0
# rtas                             18.0    3.0
# bpm                             153.0    5.0
# caise                           154.0   14.0
# issre                            45.0    0.0
# sc                               44.0    6.0
# iccs                            302.0   67.0
# cgo                              49.0    9.0
# edbt                              6.0    1.0
# ppopp                            92.0   25.0
# mswim                            45.0    1.0
# ccgrid                           77.0    5.0
# wacv                            762.0  235.0
# iccad                             0.0    0.0
# esorics                         107.0    0.0
# ecoop                            26.0    5.0
# ipco                             59.0   10.0
# esem                             33.0    6.0
# gd                               38.0    2.0
# refsq                            23.0    2.0
# fase                             80.0   14.0
# opodis                            5.0    0.0
# iwcmc                            71.0    6.0
# ace                              34.0    5.0
# prima                             3.0    0.0
# ipccc                             7.0    0.0
# wcnc                            169.0   35.0
# spire                             9.0    0.0
# rtcsa                             3.0    1.0
# adbis                            56.0    1.0
# icce                            152.0   30.0
# lopstr                            9.0    0.0
# aina                            177.0   31.0
# compsac                          81.0   17.0
# pimrc                            71.0    2.0
# cocoa                            22.0    5.0
# vtc                               4.0   33.0
# ideal                            26.0    0.0
# igarss                          124.0   23.0
# bibe                             46.0    1.0
# parco                            83.0   15.0
# iccsa                           384.0   27.0
# fmics                            19.0    1.0
# tencon                           46.0    0.0

# %%
# dizionario che facilita la creazione del grafico
dict_tot_cit_core = {}
for row,col in tot_cit_core.iterrows():
    x = {}
    for k,v in col.items():
        if k=='Rank':
            continue
        if not math.isnan(v):
            x[k] = v
    dict_tot_cit_core[row] = x

# %%
""" Funzione che crea e stampa i grafici degli andamenti delle citazioni.
Prende in input il dizionario con i dati da rappresentare, il nome della conference series e la directory
dove salvare un file png con il grafico"""

def draw_plot(dictionary,conf1,conf2,conf3,directory):
    fig,ax = plt.subplots(figsize=(8,6))
    sns.lineplot(x=list(dictionary[conf1].keys()), y=list(dictionary[conf1].values()),label=conf1)
    sns.lineplot(x=list(dictionary[conf2].keys()), y=list(dictionary[conf2].values()),label=conf2)
    sns.lineplot(x=list(dictionary[conf3].keys()), y=list(dictionary[conf3].values()),label=conf3)
    sns.scatterplot(x=list(dictionary[conf1].keys()), y=list(dictionary[conf1].values()))
    sns.scatterplot(x=list(dictionary[conf2].keys()), y=list(dictionary[conf2].values()))
    sns.scatterplot(x=list(dictionary[conf3].keys()), y=list(dictionary[conf3].values()))
    #ax.set_xticklabels(ax.get_xticklabels(), rotation=75)
    plt.xticks(rotation=75)
    plt.tight_layout()
    plt.savefig(directory)

# %%
# classe A
draw_plot(dict_tot_cit_core, 'middleware','sc','wacv','charts/conf_tot_core_a.png')

# classe B
draw_plot(dict_tot_cit_core, 'iwcmc','pimrc','icce','charts/conf_tot_core_b.png')

# classe C
draw_plot(dict_tot_cit_core, 'ideal','fmics','bibe','charts/conf_tot_core_c.png')

# %% [markdown]
# #### Commenti sull'andamento delle citazioni totali
# 1. In generale, notiamo una diminuzione delle citazioni negli anni più recenti, nello specifico dal 2017 in poi. Questa è un fatto abbastanza ovvio, in quanto degli articoli pubblicati più recentemente hanno meno probabilità di essere citati rispetto a quelli pubblicati in anni precedenti.
# Nonostante ciò, si notano delle eccezioni, nello specifico tra il 2017 e il 2018, in tutte e tre le classi di conferenze, dove notiamo un aumento.
# 2. Sono evidenti alcuni cali di citazioni a distanza di un solo anno: il più evidente è nella classe C (terzo grafico), conferenza bibe, dove c'è un passaggio da più di 500 citazioni ad un quasi azzeramento, dal 2013 al 2014. Un altro esempio lampante è nella classe B, conferenza iwcmc

# %% [markdown]
# ### Ranking CORE, citazioni medie
# Replico quello che ho appena fatto, sostituendo le citazioni totali con quelle medie

# %%
avg_cit_core = ranking_core.join(avg_cit_per_year)
# conservo solo le citazioni degli anni per i quali ho il ranking CORE
columns_to_drop = list(range(1951,2008)) + [2009,2010,2011,2012,2015,2016,2019,2022]
columns_to_drop = [str(x) for x in columns_to_drop] + ['ERA_2010_Rank']
avg_cit_core.drop(columns=columns_to_drop, inplace=True)
# elimino le conferenze per le quali non ho citazioni in quegli anni
avg_cit_core.dropna(subset=['2008','2013','2014','2017','2018','2020','2021'], inplace=True)

avg_cit_core.drop(columns=['CORE_2013_Rank','CORE_2014_Rank', 'CORE_2017_Rank','CORE_2018_Rank','CORE_2020_Rank','CORE_2021_Rank'], inplace=True)
avg_cit_core.rename(columns={'CORE_2008_Rank' : 'Rank'}, inplace=True)
avg_cit_core.sort_values(by=['Rank'], inplace=True)

# dizionario che facilita la creazione del grafico
dict_avg_cit_core = {}
for row,col in avg_cit_core.iterrows():
    x = {}
    for k,v in col.items():
        if k=='Rank':
            continue
        if not math.isnan(v):
            x[k] = v
    dict_avg_cit_core[row] = x
    
avg_cit_core
# Out:
#                                Rank       2008       2013       2014  \
# ConferenceSeriesNormalizedName
# middleware                        A   6.565217   4.152542   6.214286
# icnp                              A   9.088235   7.333333   7.662791
# rtas                              A  19.700000  13.586207  16.035714
# bpm                               A  12.511628   9.104839   4.190476
# caise                             A   3.043478   4.863309   5.714286
# issre                             A   7.376812   0.000000   4.737931
# sc                                A   8.745098   4.625000   5.377778
# iccs                              A   2.543036   6.693767   3.765794
# cgo                               A  21.333333  11.263158   1.800000
# edbt                              A   5.411765  11.864583   0.130952
# ppopp                             A  26.181818  13.780220   8.286765
# mswim                             A   5.805195   4.243902   3.850000
# ccgrid                            A   8.391304   9.438095   7.135593
# wacv                              A   9.326923  14.465753   7.840000
# iccad                             A   2.814016   5.190647   8.401869
# esorics                           A  19.756757  11.900000  12.058824
# ecoop                             A  16.297297   8.493827   9.479167
# ipco                              A   8.500000   0.000000   2.828571
# esem                              A  11.924051  11.877193   7.416667
# gd                                A   0.142857   4.111111   3.093023
# refsq                             B   9.450000   6.580645   6.125000
# fase                              B  11.351351  14.142857   7.866667
# opodis                            B   7.000000   6.650000   4.625000
# iwcmc                             B   4.544974   4.131498   3.308057
# ace                               B   5.327434   2.873684   0.000000
# prima                             B   2.775510   4.282609   1.972973
# ipccc                             B   4.360000   2.937500   2.765957
# wcnc                              B   6.622184   3.772321   3.940741
# spire                             B   5.206897   4.142857   2.200000
# rtcsa                             B   8.956522   4.111111   2.808824
# adbis                             B   2.166667   2.059701   2.194444
# icce                              B   2.137324   1.746296   2.776337
# lopstr                            B   4.062500   2.461538   1.450000
# aina                              B   4.193182   4.563084   4.795527
# compsac                           B   3.500000   3.396429   3.394619
# pimrc                             B   5.649435   4.094164   3.180952
# cocoa                             B   2.978261   1.432432   1.965517
# vtc                               B   5.818847   5.029867   3.461187
# ideal                             C   3.328358   3.625000   2.714286
# igarss                            C   2.507429   1.274821   1.309490
# bibe                              C   2.158730   2.792350   8.500000
# parco                             C  13.482143   4.428571   7.867470
# iccsa                             C   3.235714   3.468085   2.578680
# fmics                             C   0.000000   4.538462   4.533333
# tencon                            C   2.819521   1.701903   1.583691
#
#                                     2017      2018      2020      2021
# ConferenceSeriesNormalizedName
# middleware                      4.206349  2.814815  0.542857  0.021277
# icnp                            2.852941  1.571429  0.269841  0.000000
# rtas                            3.564103  2.285714  0.620690  0.050000
# bpm                             4.392523  2.591549  1.593750  0.058140
# caise                           5.560000  3.098039  1.770115  0.155556
# issre                           1.538462  1.910112  0.391304  0.000000
# sc                              1.062500  1.707317  0.369748  0.041096
# iccs                            3.835664  0.874116  0.809651  0.211356
# cgo                             0.259259  9.666667  1.960000  0.257143
# edbt                            0.296703  0.197802  0.067416  0.011111
# ppopp                           3.699029  3.250000  1.672727  0.531915
# mswim                           1.620253  1.470588  0.900000  0.017241
# ccgrid                          5.127660  1.833333  0.740385  0.054348
# wacv                            8.467105  6.642241  2.026596  0.547786
# iccad                           1.598361  1.549153  0.000000  0.000000
# esorics                         6.600000  2.754098  0.743056  0.000000
# ecoop                           1.333333  1.030303  0.787879  0.217391
# ipco                            3.888889  1.000000  1.512821  0.294118
# esem                            6.000000  3.637931  0.767442  0.157895
# gd                              1.344262  0.839506  0.361905  2.000000
# refsq                           4.607143  2.304348  1.045455  0.133333
# fase                            6.384615  1.980769  1.355932  0.583333
# opodis                          0.218750  0.254545  0.147059  0.000000
# iwcmc                           0.052632  1.513208  0.410405  0.014851
# ace                             2.541667  4.733333  1.416667  0.217391
# prima                           1.725000  1.272727  0.120000  0.000000
# ipccc                           1.961039  0.764045  0.120690  0.000000
# wcnc                            2.164875  1.394511  0.330078  0.082742
# spire                           2.357143  1.285714  0.428571  0.000000
# rtcsa                           2.000000  1.600000  0.125000  0.037037
# adbis                           1.527027  1.169492  0.861538  0.020408
# icce                            1.104688  0.859649  0.182692  0.087209
# lopstr                          3.105263  1.166667  0.529412  0.000000
# aina                            2.595819  1.706522  0.699605  0.156566
# compsac                         1.921769  1.582317  0.289286  0.059441
# pimrc                           1.348653  0.776042  0.239057  0.007663
# cocoa                           1.051948  0.744681  0.366667  0.089286
# vtc                             1.173630  0.786344  1.000000  0.036184
# ideal                           1.279412  1.181818  0.276596  0.000000
# igarss                          0.827731  0.616451  0.075702  0.010688
# bibe                            1.459184  0.791667  0.226601  0.009346
# parco                           3.006623  2.521739  0.965116  0.454545
# iccsa                           2.034211  1.832753  0.747082  0.054767
# fmics                           2.642857  3.157895  1.583333  0.062500
# tencon                          0.975439  0.650307  0.181102  0.000000

# %%
# classe A
draw_plot(dict_avg_cit_core, 'middleware','sc','wacv','charts/conf_avg_core_a.png')

# classe B
draw_plot(dict_avg_cit_core, 'iwcmc','pimrc','icce','charts/conf_avg_core_b.png')

# classe C
draw_plot(dict_avg_cit_core, 'ideal','fmics','bibe','charts/conf_avg_core_c.png')

# %% [markdown]
# #### Commenti sull'andamento delle citazioni medie
# 1. Anche qui vale il ragionamento della discesa delle citazioni negli anni più recenti, con qualche eccezione (vedi dal 2017 al 2018, in tutte e tre le classi).
# 2. Si nota un netto aumento di citazioni medie da un anno al successivo, nello specifico dal 2013 al 2014: l'esempio più evidente è nella classe C conferenza bibe.
# 3. Per il resto, l'andamento è abbastanza coerente con quello delle citazioni totali.

# %% [markdown]
# ### Andamento delle citazioni totali per il ranking GRIN
# Non avendo il rating per vari anni come per CORE, qui mi limiterò semplicemente a mostrare per ogni classe (1,2,3) dei casi particolari di andamenti di citazioni negli anni

# %%
ranking_grin = pd.read_csv('out_conference_series_with_grin_rank.csv', index_col='ConferenceSeriesNormalizedName')
ranking_grin.drop(['Unnamed: 0','GrinRating'], axis=1, inplace=True)
ranking_grin.dropna(subset=['GrinClass'], inplace=True)

#creo il dataset delle citazioni totali che servirà per l'analisi
tot_cit_grin = ranking_grin.join(tot_cit_per_year)
tot_cit_grin
# Out:
#                                 GrinClass  1951  1952  1953  1954  1955  1956  \
# ConferenceSeriesNormalizedName
# disc                                  3.0   NaN   NaN   NaN   NaN   NaN   NaN
# esa                                   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# dexa                                  3.0   NaN   NaN   NaN   NaN   NaN   NaN
# interact                              3.0   NaN   NaN   NaN   NaN   NaN   NaN
# fct                                   3.0   NaN   NaN   NaN   NaN   NaN   NaN
# ...                                   ...   ...   ...   ...   ...   ...   ...
# jelia                                 3.0   NaN   NaN   NaN   NaN   NaN   NaN
# dbsec                                 3.0   NaN   NaN   NaN   NaN   NaN   NaN
# lpar                                  3.0   NaN   NaN   NaN   NaN   NaN   NaN
# sirocco                               3.0   NaN   NaN   NaN   NaN   NaN   NaN
# hotos                                 3.0   NaN   NaN   NaN   NaN   NaN   NaN
#
#                                 1957  1958  1959  ...    2013   2014    2015  \
# ConferenceSeriesNormalizedName                    ...
# disc                             NaN   NaN   NaN  ...   365.0  340.0   299.0
# esa                              NaN   NaN   NaN  ...   432.0  366.0   405.0
# dexa                             NaN   NaN   NaN  ...   327.0  241.0     0.0
# interact                         NaN   NaN   NaN  ...  2617.0  969.0  1891.0
# fct                              NaN   NaN   NaN  ...    74.0    NaN    41.0
# ...                              ...   ...   ...  ...     ...    ...     ...
# jelia                            NaN   NaN   NaN  ...     NaN    NaN     NaN
# dbsec                            NaN   NaN   NaN  ...   150.0  132.0    74.0
# lpar                             NaN   NaN   NaN  ...     0.0    NaN     6.0
# sirocco                          NaN   NaN   NaN  ...     NaN  122.0   159.0
# hotos                            NaN   NaN   NaN  ...     NaN    NaN     NaN
#
#                                  2016    2017   2018    2019   2020  2021  \
# ConferenceSeriesNormalizedName
# disc                              NaN   168.0  130.0    64.0    NaN   NaN
# esa                              15.0    40.0   25.0    29.0    NaN   2.0
# dexa                            212.0   201.0  153.0    89.0   25.0   NaN
# interact                        862.0  1009.0  409.0  1617.0  878.0  17.0
# fct                               NaN    56.0    NaN    28.0    NaN   3.0
# ...                               ...     ...    ...     ...    ...   ...
# jelia                             0.0     NaN    NaN     NaN    NaN   NaN
# dbsec                            52.0    88.0    NaN    38.0   18.0   2.0
# lpar                              NaN     NaN    NaN     NaN    0.0   NaN
# sirocco                          89.0    46.0    NaN    40.0   17.0   NaN
# hotos                             NaN   185.0    NaN   111.0    NaN  28.0
#
#                                 2022
# ConferenceSeriesNormalizedName
# disc                             NaN
# esa                              NaN
# dexa                             NaN
# interact                         NaN
# fct                              NaN
# ...                              ...
# jelia                            NaN
# dbsec                            NaN
# lpar                             NaN
# sirocco                          NaN
# hotos                            NaN
#
# [536 rows x 73 columns]

# %%
# dizionario che facilita la creazione del grafico dell'andamento delle citazioni totali
dict_tot_cit_grin = {}
for row,col in tot_cit_grin.iterrows():
    x = {}
    for k,v in col.items():
        if k=='GrinClass':
            continue
        x[k] = v
    dict_tot_cit_grin[row] = x

# %%
# classe 3
draw_plot(dict_tot_cit_grin, 'icfem','vrst','mascots','charts/conf_tot_grin_3.png')

# classe 2
draw_plot(dict_tot_cit_grin, 'ipdps','grid','icdar','charts/conf_tot_grin_2.png')

# classe 1
draw_plot(dict_tot_cit_grin, 'vldb','colt','eurocrypt','charts/conf_tot_grin_1.png')

# %% [markdown]
# #### Commenti sull'andamento delle citazioni totali
# 1. Anche qui notiamo una generale diminuzione delle citazioni negli anni più recenti, in tutte e tre le classi, con qualche piccola eccezione, ad esempio la conferenza mascots nella classe 3, la quale quasi raddoppia le citazioni dal 2017 al 2018.
# 2. Spiccano molto degli abbassamenti e rialzi nel giro di pochissimo tempo: i casi più evidenti sono nella classe 1. Anche guardando nella classe 2 abbiamo la conferenza ipdps che nel giro di quattro anni vede aumentare le citazioni da circa 250 a oltre 1600

# %%
# effettuo la stessa analisi per le citazioni medie
avg_cit_grin = ranking_grin.join(avg_cit_per_year)
avg_cit_grin.sort_values('GrinClass', inplace=True)
avg_cit_grin

# dizionario che facilita la creazione del grafico dell'andamento delle citazioni medie
dict_avg_cit_grin = {}
for row,col in avg_cit_grin.iterrows():
    x = {}
    for k,v in col.items():
        if k=='GrinClass':
            continue
        x[k] = v
    dict_avg_cit_grin[row] = x

# %%
#classe 3
draw_plot(dict_avg_cit_grin, 'icfem','vrst','cgi','a')
# classe 2
draw_plot(dict_avg_cit_grin, 'bpm','grid','fc','a')
# classe 1
draw_plot(dict_avg_cit_grin, 'vldb','colt','eurocrypt','a')

# %% [markdown]
# #### Commento sull'andamento delle citazioni medie
# In questo caso, in tutte e tre le classi abbiamo dei cambiamenti molto bruschi da un anno all'altro (o comunque a distanza di pochi anni), sia in aumento, sia in diminuzione.
# NB. In quest'ultima analisi di citazioni medie le conferenze non sono le stesse delle cit. totali, a differenza di quanto avevo fatto con il ranking CORE. Non ho analizzato le stesse perchè in questo caso nelle citazioni medie non c'erano commenti particolari da fare.

# %% [markdown]
# ## Confronto tra arrivi di turisti e citazioni  medie
# In questa sezione cercherò di replicare ciò che è stato fatto per la fig.3 del paper, che mostra l'andamento delle citazioni medie di una conferenza negli anni, comparato all'indice Size Wikipedia Page (SWP) di un determinato luogo. In questo caso però sostituirò il SWP con l'arrivo di turisti (TA) in uno Stato.
# NB. I TA attualmente in possesso vanno dal 1995 al 2020, a differenza di quelli del paper, che si riferiscono solo all'anno 2018

# %%
# creo due dataframe che mi facilitano la costruzione dei grafici.
# Il primo contiene le conferenze, l'anno in cui si sono tenute e il relativo Stato, il secondo gli indici turistici
df_COCI['Country'] = df_COCI['ConferenceLocation'].str.split(',').str[-1].str.lstrip()

conf_country_year = df_COCI.loc[:, ['Year','Country']]
conf_country_year = conf_country_year.reset_index().drop_duplicates().set_index('ConferenceSeriesNormalizedName')
conf_country_year.sort_index(inplace=True)
conf_country_year = conf_country_year[(conf_country_year['Year'] >= 1995) & (conf_country_year['Year'] <= 2020)]
touristic_indexes_countries = pd.read_csv('all_indexes_by_country.csv')
touristic_indexes_countries.drop(columns=['ConferenceLocation'],inplace=True)
touristic_indexes_countries.drop_duplicates(inplace=True)


""" Dizionario che contiene l'arrivo di turisti nello Stato (TA) dove si è tenuta la conferenza in quel
determinato anno. Nel dataframe gli arrivi sono espressi in migliaia, qui invece in decine di milioni,
per far sì che sull'asse y i valori siano più simili a quelli delle citazioni medie 
(le cit. medie difficilmente sono più di 20, gli arrivi espressi in migliaia invece avevano valori molto alti)"""

dict_TA_conf_year = {}
for row,col in conf_country_year.iterrows():
    if row not in dict_TA_conf_year:
        x = {year : np.nan for year in [str(x) for x in list(range(1995,2021))]}
        dict_TA_conf_year[row] = x
        x[str(col['Year'])] = (touristic_indexes_countries[str(col['Year'])][touristic_indexes_countries['Country'] == col['Country']].values[0])/10000
    else:
        dict_TA_conf_year[row][str(col['Year'])] = (touristic_indexes_countries[str(col['Year'])][touristic_indexes_countries['Country'] == col['Country']].values[0])/10000

dict_TA_conf_year
# Out:
# {'16th-ibcast-2019': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dgis': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 2.5298,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dic': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': 0.6219,
#   '2012': nan,
#   '2013': 17.930990700000002,
#   '2014': nan,
#   '2015': nan,
#   '2016': 17.5261488,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dica': {'1995': nan,
#   '1996': nan,
#   '1997': 8.2525,
#   '1998': 7.4767,
#   '1999': 7.5796,
#   '2000': 7.8343,
#   '2001': 7.0975,
#   '2002': 6.4434,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': nan,
#   '2008': 17.5703,
#   '2009': nan,
#   '2010': 16.2275,
#   '2011': 14.7271416,
#   '2012': 17.1629897,
#   '2013': 17.930990700000002,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': 4.5037},
#  '3dim': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': 4.9055,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 3.616,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 15.326,
#   '2018': 9.32286,
#   '2019': 3.243,
#   '2020': nan},
#  '3dimpvt': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': 13.5423,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dor': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': 3.1886,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 20.7274,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dph': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dpvt': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': 6.3561,
#   '2003': nan,
#   '2004': 1.4268,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dtv': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 4.5984,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dtv-con': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 3.1138,
#   '2009': nan,
#   '2010': 0.6182,
#   '2011': 3.6769,
#   '2012': nan,
#   '2013': nan,
#   '2014': 4.5984,
#   '2015': nan,
#   '2016': nan,
#   '2017': 3.0736,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dui': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': 17.5299,
#   '2008': 17.5703,
#   '2009': 16.0508,
#   '2010': 16.2275,
#   '2011': nan,
#   '2012': 17.1629897,
#   '2013': 17.930990700000002,
#   '2014': 17.8311354,
#   '2015': 20.3302,
#   '2016': 17.5261488,
#   '2017': 17.4291746,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '3dv': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 17.930990700000002,
#   '2014': 1.3413,
#   '2015': 20.3302,
#   '2016': nan,
#   '2017': 15.326,
#   '2018': 9.32286,
#   '2019': 3.243,
#   '2020': nan},
#  '3pgcic': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 0.8611,
#   '2011': 9.9187,
#   '2012': 2.5318,
#   '2013': nan,
#   '2014': 12.8499,
#   '2015': 7.7743,
#   '2016': 1.7242,
#   '2017': 12.1717,
#   '2018': 1.1067,
#   '2019': nan,
#   '2020': 0.41158},
#  '5gwf': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '5gwn': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 15.326,
#   '2018': nan,
#   '2019': 16.2538,
#   '2020': nan},
#  '6gsummit': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '6th': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 1.581,
#   '2019': nan,
#   '2020': nan},
#  '8th': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  '9-icgt-2018': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 1.581,
#   '2019': nan,
#   '2020': nan},
#  'a-most': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 7.1484,
#   '2006': nan,
#   '2007': 3.2778,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'a-sscc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': 0.9795,
#   '2012': nan,
#   '2013': nan,
#   '2014': 0.991,
#   '2015': nan,
#   '2016': 2.4039,
#   '2017': 1.3336,
#   '2018': 1.1067,
#   '2019': 16.2538,
#   '2020': nan},
#  'a2cwic': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 0.5881,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'a4cloud': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 10.7144,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aaa-idea': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 7.1484,
#   '2006': 6.6353,
#   '2007': nan,
#   '2008': nan,
#   '2009': 9.1899,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aaai': {'1995': nan,
#   '1996': 8.2756,
#   '1997': nan,
#   '1998': 7.4767,
#   '1999': 7.5796,
#   '2000': 7.8343,
#   '2001': nan,
#   '2002': 4.4896,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': 7.1484,
#   '2006': 18.3178,
#   '2007': 3.0373,
#   '2008': 17.5703,
#   '2009': nan,
#   '2010': 16.2275,
#   '2011': 14.7271416,
#   '2012': 2.5318,
#   '2013': 17.930990700000002,
#   '2014': 2.5558,
#   '2015': 17.686452600000003,
#   '2016': 17.5261488,
#   '2017': 17.4291746,
#   '2018': 16.9324918,
#   '2019': 16.5478,
#   '2020': 4.5037},
#  'aaate': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 4.8345,
#   '2016': nan,
#   '2017': 4.108,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aacc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aadebug': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 7.1484,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aadeca': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 1.0394,
#   '2019': nan,
#   '2020': nan},
#  'aadios': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': 0.8867,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aaecc': {'1995': nan,
#   '1996': nan,
#   '1997': 15.7551,
#   '1998': nan,
#   '1999': 7.5796,
#   '2000': nan,
#   '2001': 0.4856,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': 0.5244,
#   '2008': nan,
#   '2009': 9.1899,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aag': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': 19.7522,
#   '2013': nan,
#   '2014': 3.5337,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aaim': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 12.0292,
#   '2006': 12.4942,
#   '2007': 17.5299,
#   '2008': 13.0027,
#   '2009': 16.0508,
#   '2010': 13.3762,
#   '2011': nan,
#   '2012': 13.2405,
#   '2013': 12.9078,
#   '2014': 2.5558,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 16.9324918,
#   '2019': 16.2538,
#   '2020': 3.0402},
#  'aaip': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 3.1072,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aamas': {'1995': nan,
#   '1996': nan,
#   '1997': 8.2525,
#   '1998': 7.4767,
#   '1999': 7.5796,
#   '2000': 7.458,
#   '2001': 2.2835,
#   '2002': 6.3561,
#   '2003': 0.4746,
#   '2004': 6.7606,
#   '2005': nan,
#   '2006': 0.7334,
#   '2007': 17.5299,
#   '2008': nan,
#   '2009': 4.0624,
#   '2010': 2.5621,
#   '2011': 0.6087,
#   '2012': 9.8128,
#   '2013': 17.930990700000002,
#   '2014': 20.6599,
#   '2015': 4.1114,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 3.243,
#   '2020': 0.0996},
#  'aares': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 0.9466,
#   '2020': nan},
#  'ab': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'abials': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'abict': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': 6.739,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'abp': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'abz': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 2.5621,
#   '2011': nan,
#   '2012': 7.6293,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'ac': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': 2.8014,
#   '2001': nan,
#   '2002': nan,
#   '2003': 0.4746,
#   '2004': 6.7606,
#   '2005': nan,
#   '2006': nan,
#   '2007': 13.1873,
#   '2008': nan,
#   '2009': 7.1692,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 3.9129,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aca': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 12.8499,
#   '2015': nan,
#   '2016': 14.1774,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acal': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 0.549,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 0.7449,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acbd': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 12.9078,
#   '2014': 12.8499,
#   '2015': 13.382,
#   '2016': 14.1774,
#   '2017': 15.326,
#   '2018': nan,
#   '2019': 16.2538,
#   '2020': 3.0402},
#  'acc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': 7.0975,
#   '2002': nan,
#   '2003': nan,
#   '2004': 10.9038,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': 17.5299,
#   '2008': 17.5703,
#   '2009': 16.0508,
#   '2010': 16.2275,
#   '2011': nan,
#   '2012': 2.5318,
#   '2013': 17.930990700000002,
#   '2014': 17.8311354,
#   '2015': 17.686452600000003,
#   '2016': 17.5261488,
#   '2017': 17.4291746,
#   '2018': 16.9324918,
#   '2019': 16.5478,
#   '2020': nan},
#  'accas': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'accessnets': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 1.7284,
#   '2007': 3.0373,
#   '2008': 17.5703,
#   '2009': 12.6476,
#   '2010': 3.9904,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'accs': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'accv': {'1995': nan,
#   '1996': nan,
#   '1997': 5.7588,
#   '1998': 6.3478,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': 0.4841,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 0.4626,
#   '2007': 0.8347,
#   '2008': nan,
#   '2009': 12.6476,
#   '2010': 0.253,
#   '2011': nan,
#   '2012': 1.114,
#   '2013': 1.2176,
#   '2014': nan,
#   '2015': nan,
#   '2016': 1.069,
#   '2017': 1.074,
#   '2018': 0.9246,
#   '2019': 0.9466,
#   '2020': 0.41158},
#  'acdc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 9.1899,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'ace': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': 0.4931,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 9.2563,
#   '2006': 18.3178,
#   '2007': nan,
#   '2008': 0.8351,
#   '2009': 0.2473,
#   '2010': 0.5567,
#   '2011': nan,
#   '2012': nan,
#   '2013': 0.6482,
#   '2014': 0.2854,
#   '2015': nan,
#   '2016': 2.4039,
#   '2017': 4.108,
#   '2018': 0.9246,
#   '2019': 0.9466,
#   '2020': 0.1828},
#  'aces': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 3.5046,
#   '2020': 0.6102},
#  'acfie': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 13.0027,
#   '2009': nan,
#   '2010': 13.3762,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acg': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 0.3378,
#   '2006': 0.352,
#   '2007': nan,
#   '2008': nan,
#   '2009': 9.1899,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 16.2538,
#   '2020': 3.0402},
#  'achi': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 19.3571,
#   '2009': 8.8044,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 8.4925,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acii': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 12.0292,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': 14.7271416,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 13.382,
#   '2016': nan,
#   '2017': 17.4291746,
#   '2018': nan,
#   '2019': 4.0857,
#   '2020': nan},
#  'aciids': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 0.3747,
#   '2010': 0.505,
#   '2011': 0.9795,
#   '2012': 0.7311,
#   '2013': nan,
#   '2014': nan,
#   '2015': 1.0407,
#   '2016': 1.0013,
#   '2017': 2.8691,
#   '2018': nan,
#   '2019': 1.6107,
#   '2020': nan},
#  'acirs': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 3.1881,
#   '2020': nan},
#  'acisicis': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 0.6023,
#   '2006': nan,
#   '2007': 0.5644,
#   '2008': nan,
#   '2009': 12.6476,
#   '2010': 0.8611,
#   '2011': 13.5423,
#   '2012': nan,
#   '2013': 1.0364,
#   '2014': nan,
#   '2015': 17.686452600000003,
#   '2016': nan,
#   '2017': 15.326,
#   '2018': nan,
#   '2019': 16.2538,
#   '2020': nan},
#  'acisp': {'1995': nan,
#   '1996': 0.4165,
#   '1997': 0.4318,
#   '1998': 0.4167,
#   '1999': 0.4459,
#   '2000': 0.4931,
#   '2001': 0.4856,
#   '2002': 0.4841,
#   '2003': 0.4746,
#   '2004': 0.5215,
#   '2005': 0.5499,
#   '2006': 0.5532,
#   '2007': nan,
#   '2008': 0.5586,
#   '2009': 0.549,
#   '2010': 0.579,
#   '2011': 0.5771,
#   '2012': 0.6032,
#   '2013': 0.6482,
#   '2014': 0.6922,
#   '2015': 0.7449,
#   '2016': 0.8269,
#   '2017': 0.3723,
#   '2018': 0.9246,
#   '2019': 0.3888,
#   '2020': 0.1828},
#  'acit': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 3.7202,
#   '2020': nan},
#  'acit2': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 15.8606,
#   '2019': 16.5478,
#   '2020': nan},
#  'acit3': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': 0.3677},
#  'acity': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acivs': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 19.3571,
#   '2009': 19.2369,
#   '2010': 0.579,
#   '2011': nan,
#   '2012': 2.575,
#   '2013': 7.231,
#   '2014': nan,
#   '2015': 8.1068,
#   '2016': 8.4925,
#   '2017': nan,
#   '2018': 21.1998,
#   '2019': nan,
#   '2020': 0.0996},
#  'acl': {'1995': 7.9732,
#   '1996': 8.2756,
#   '1997': 6.2415,
#   '1998': 4.8064,
#   '1999': 7.5796,
#   '2000': 8.3444,
#   '2001': nan,
#   '2002': 6.4434,
#   '2003': 0.5212,
#   '2004': 9.925,
#   '2005': 7.1484,
#   '2006': 0.5532,
#   '2007': 2.2625,
#   '2008': 17.5703,
#   '2009': nan,
#   '2010': nan,
#   '2011': 14.7271416,
#   '2012': 1.114,
#   '2013': 0.9192,
#   '2014': 17.8311354,
#   '2015': 13.382,
#   '2016': nan,
#   '2017': 3.1081,
#   '2018': 0.9246,
#   '2019': 9.5399,
#   '2020': 4.5037},
#  'acl-alw': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-bsnlp': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 12.1717,
#   '2018': nan,
#   '2019': 9.5399,
#   '2020': nan},
#  'acl-bucc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 13.382,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-clinicalnlp': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': 11.7109},
#  'acl-clpsych': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 16.9324918,
#   '2019': nan,
#   '2020': nan},
#  'acl-cmcl': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 17.8311354,
#   '2015': nan,
#   '2016': nan,
#   '2017': 12.1717,
#   '2018': 16.9324918,
#   '2019': nan,
#   '2020': nan},
#  'acl-codeswitch': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 0.2839,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-cvsc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 1.9945,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-deeplo': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 0.9246,
#   '2019': nan,
#   '2020': nan},
#  'acl-figlang': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 16.9324918,
#   '2019': nan,
#   '2020': nan},
#  'acl-ldl': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 13.382,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-louhi': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 1.9945,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-mrqa': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 16.2538,
#   '2020': nan},
#  'acl-multiling': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 12.1717,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-nlpcss': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 17.5261488,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-peoples': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 16.9324918,
#   '2019': nan,
#   '2020': nan},
#  'acl-pitr': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 1.9945,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-sighan': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 12.8499,
#   '2015': 13.382,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-socialnlp': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 17.686452600000003,
#   '2016': 17.5261488,
#   '2017': 12.1717,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-swaie': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl-vl': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 12.1717,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acl2': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acling': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 2.1805,
#   '2018': 2.3092,
#   '2019': nan,
#   '2020': nan},
#  'aclnews': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'aclnut': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 13.382,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': 16.2538,
#   '2020': nan},
#  'aclwac': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 1.9945,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acm': {'1995': 7.9732,
#   '1996': 8.2756,
#   '1997': 8.2525,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': 3.0373,
#   '2008': nan,
#   '2009': 16.0508,
#   '2010': 16.2275,
#   '2011': 14.7271416,
#   '2012': 3.2221,
#   '2013': nan,
#   '2014': 17.8311354,
#   '2015': 20.3302,
#   '2016': nan,
#   '2017': 15.326,
#   '2018': nan,
#   '2019': 16.5478,
#   '2020': nan},
#  'acm-bcb': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': 17.1629897,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acm-l': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': 17.5299,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmace': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 9.2563,
#   '2006': 18.3178,
#   '2007': nan,
#   '2008': 0.8351,
#   '2009': nan,
#   '2010': 0.5567,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 2.4039,
#   '2017': 4.108,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmdev': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 3.0398,
#   '2011': nan,
#   '2012': 17.1629897,
#   '2013': 1.4318,
#   '2014': 17.8311354,
#   '2015': 3.6792,
#   '2016': 0.134,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmdis': {'1995': 7.9732,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': 7.8343,
#   '2001': nan,
#   '2002': 9.7908,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': nan,
#   '2006': 18.3178,
#   '2007': nan,
#   '2008': 0.9729,
#   '2009': nan,
#   '2010': 2.673,
#   '2011': nan,
#   '2012': 3.2221,
#   '2013': nan,
#   '2014': 2.5558,
#   '2015': nan,
#   '2016': 0.8269,
#   '2017': 4.108,
#   '2018': 15.8606,
#   '2019': 16.5478,
#   '2020': nan},
#  'acmicec': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': 6.2082,
#   '2004': nan,
#   '2005': 12.0292,
#   '2006': 3.339,
#   '2007': 17.5299,
#   '2008': nan,
#   '2009': 0.4395,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 17.8311354,
#   '2015': nan,
#   '2016': 1.7242,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmicn': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 12.9078,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmidc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 0.5345,
#   '2007': 2.7138,
#   '2008': 17.5703,
#   '2009': nan,
#   '2010': 9.3744,
#   '2011': 14.7271416,
#   '2012': nan,
#   '2013': 17.930990700000002,
#   '2014': 2.807,
#   '2015': 17.686452600000003,
#   '2016': 3.9129,
#   '2017': nan,
#   '2018': nan,
#   '2019': 16.5478,
#   '2020': 1.1101},
#  'acml': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 12.6476,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 1.3336,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmmpc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': 2.5209,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmmsp': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': 7.1484,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmpolicy': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': 7.4767,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmpt': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 2.439,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acmse': {'1995': 7.9732,
#   '1996': nan,
#   '1997': 8.2525,
#   '1998': 7.4767,
#   '1999': 7.5796,
#   '2000': 7.8343,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': 7.1484,
#   '2006': 18.3178,
#   '2007': 17.5299,
#   '2008': 17.5703,
#   '2009': 16.0508,
#   '2010': 16.2275,
#   '2011': 14.7271416,
#   '2012': nan,
#   '2013': 17.930990700000002,
#   '2014': 17.8311354,
#   '2015': nan,
#   '2016': nan,
#   '2017': 17.4291746,
#   '2018': 16.9324918,
#   '2019': 16.5478,
#   '2020': 4.5037},
#  'acmturc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 15.8606,
#   '2019': 16.2538,
#   '2020': 3.0402},
#  'acn': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 0.8611,
#   '2011': 2.281,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acns': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': 9.1662,
#   '2004': 10.9038,
#   '2005': 7.1484,
#   '2006': nan,
#   '2007': 13.1873,
#   '2008': 17.5703,
#   '2009': 19.2369,
#   '2010': 13.3762,
#   '2011': 9.9187,
#   '2012': nan,
#   '2013': 2.5167,
#   '2014': nan,
#   '2015': 17.686452600000003,
#   '2016': 3.9129,
#   '2017': 2.8691,
#   '2018': nan,
#   '2019': 0.4531,
#   '2020': 3.8419},
#  'acom': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acosis': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 1.0677,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acpc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'acpr': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
# ...
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 11.5561,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'coregrid': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 6.4606,
#   '2006': 6.5115,
#   '2007': nan,
#   '2008': 9.767,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cores': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 6.4606,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 5.384,
#   '2010': nan,
#   '2011': 6.0745,
#   '2012': nan,
#   '2013': 7.231,
#   '2014': nan,
#   '2015': 7.7743,
#   '2016': 8.0476,
#   '2017': 8.3804,
#   '2018': nan,
#   '2019': 8.8515,
#   '2020': nan},
#  'coria': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 19.0282,
#   '2005': 18.5829,
#   '2006': 19.3882,
#   '2007': nan,
#   '2008': 19.3571,
#   '2009': nan,
#   '2010': 0.864,
#   '2011': 19.6595,
#   '2012': 19.7522,
#   '2013': nan,
#   '2014': 20.6599,
#   '2015': 20.3302,
#   '2016': 20.3042,
#   '2017': 20.7274,
#   '2018': 21.1998,
#   '2019': 21.7877,
#   '2020': nan},
#  'corr': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 7.1692,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 1.0507,
#   '2015': 0.3371,
#   '2016': 3.0142,
#   '2017': nan,
#   '2018': 3.1274,
#   '2019': 3.243,
#   '2020': nan},
#  'cosaami-2018': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 1.5004,
#   '2019': nan,
#   '2020': nan},
#  'cosade': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 20.441,
#   '2014': 20.6599,
#   '2015': nan,
#   '2016': nan,
#   '2017': 20.7274,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cosit': {'1995': nan,
#   '1996': nan,
#   '1997': 8.2525,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 7.1484,
#   '2006': nan,
#   '2007': 0.5644,
#   '2008': nan,
#   '2009': 19.2369,
#   '2010': nan,
#   '2011': 14.7271416,
#   '2012': nan,
#   '2013': 3.3567,
#   '2014': nan,
#   '2015': 17.686452600000003,
#   '2016': nan,
#   '2017': 8.9931,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cosn': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 17.930990700000002,
#   '2014': nan,
#   '2015': 17.686452600000003,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cost': {'1995': nan,
#   '1996': 5.5077,
#   '1997': 2.4244,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 2.185,
#   '2009': nan,
#   '2010': 7.3225,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 8.3804,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cp': {'1995': nan,
#   '1996': 8.2756,
#   '1997': nan,
#   '1998': 5.8499,
#   '1999': 7.5796,
#   '2000': nan,
#   '2001': 0.2841,
#   '2002': 6.4434,
#   '2003': nan,
#   '2004': 3.8845,
#   '2005': 9.2563,
#   '2006': 19.3882,
#   '2007': 17.5299,
#   '2008': 0.5586,
#   '2009': nan,
#   '2010': 3.0398,
#   '2011': 7.5866,
#   '2012': 2.5318,
#   '2013': 1.8803,
#   '2014': 20.6599,
#   '2015': nan,
#   '2016': 20.3042,
#   '2017': 0.8815,
#   '2018': 21.1998,
#   '2019': 16.5478,
#   '2020': nan},
#  'cpa': {'1995': 0.3726,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 3.1888,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 3.3567,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cpaior': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 19.0282,
#   '2005': 2.4747,
#   '2006': nan,
#   '2007': nan,
#   '2008': 19.3571,
#   '2009': 16.0508,
#   '2010': 7.3225,
#   '2011': nan,
#   '2012': 19.7522,
#   '2013': 17.930990700000002,
#   '2014': nan,
#   '2015': 10.9834,
#   '2016': nan,
#   '2017': 8.9931,
#   '2018': nan,
#   '2019': 3.4005,
#   '2020': nan},
#  'cpe': {'1995': nan,
#   '1996': nan,
#   '1997': 15.7551,
#   '1998': 6.8068,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': 2.418,
#   '2003': 6.2082,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cpem': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': 7.4767,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': 4.4896,
#   '2003': nan,
#   '2004': 2.7755,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 17.5703,
#   '2009': nan,
#   '2010': 0.8798,
#   '2011': nan,
#   '2012': 17.1629897,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 3.0142,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cpm': {'1995': nan,
#   '1996': 8.2756,
#   '1997': nan,
#   '1998': 7.4767,
#   '1999': nan,
#   '2000': 4.8638,
#   '2001': 0.1219,
#   '2002': 0.5239,
#   '2003': 9.233,
#   '2004': 1.7517,
#   '2005': 0.6023,
#   '2006': 9.6152,
#   '2007': 3.0373,
#   '2008': 7.0719,
#   '2009': 19.2369,
#   '2010': 16.2275,
#   '2011': 7.5866,
#   '2012': 0.7636,
#   '2013': nan,
#   '2014': 3.2421,
#   '2015': 8.1068,
#   '2016': 0.307,
#   '2017': 8.3804,
#   '2018': nan,
#   '2019': nan,
#   '2020': 1.5595},
#  'cpp': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': 0.6087,
#   '2012': 0.8358,
#   '2013': 0.6482,
#   '2014': nan,
#   '2015': nan,
#   '2016': 17.5261488,
#   '2017': 20.7274,
#   '2018': 16.9324918,
#   '2019': nan,
#   '2020': 4.5037},
#  'cpr': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': 6.2082,
#   '2004': 6.7606,
#   '2005': 7.1484,
#   '2006': 18.3178,
#   '2007': 17.5299,
#   '2008': nan,
#   '2009': nan,
#   '2010': 2.5621,
#   '2011': 14.7271416,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': 17.686452600000003,
#   '2016': 17.5261488,
#   '2017': nan,
#   '2018': 16.9324918,
#   '2019': 16.5478,
#   '2020': nan},
#  'cpre': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 6.7606,
#   '2005': 7.1484,
#   '2006': 18.3178,
#   '2007': 17.5299,
#   '2008': 17.5703,
#   '2009': 16.0508,
#   '2010': 16.2275,
#   '2011': 14.7271416,
#   '2012': 17.1629897,
#   '2013': 17.930990700000002,
#   '2014': 17.8311354,
#   '2015': 17.686452600000003,
#   '2016': 17.5261488,
#   '2017': 17.4291746,
#   '2018': 16.9324918,
#   '2019': nan,
#   '2020': nan},
#  'cpscip': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': 1.1101},
#  'cpsna': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': 2.4039,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'cpsweek': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 17.4291746,
#   '2018': nan,
#   '2019': 3.243,
#   '2020': nan},
#  'cras': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 4.0283,
#   '2019': nan,
#   '2020': nan},
#  'crc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': 15.326,
#   '2018': nan,
#   '2019': 3.1881,
#   '2020': 3.0402},
#  'cris': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 2.673,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'crisis': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': 19.2369,
#   '2010': 2.5621,
#   '2011': 0.7611,
#   '2012': nan,
#   '2013': 20.441,
#   '2014': 7.7694,
#   '2015': 2.6114,
#   '2016': nan,
#   '2017': nan,
#   '2018': 21.1998,
#   '2019': nan,
#   '2020': 11.7109},
#  'critical': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': 2.6927,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'critis': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 1.7284,
#   '2007': 9.8907,
#   '2008': 7.0719,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 0.2558,
#   '2015': nan,
#   '2016': 20.3042,
#   '2017': 8.9931,
#   '2018': 0.6115,
#   '2019': nan,
#   '2020': 1.1101},
#  'criwg': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 0.1771,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': 17.5703,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 0.271,
#   '2014': 0.4601,
#   '2015': nan,
#   '2016': 2.4039,
#   '2017': 3.1081,
#   '2018': nan,
#   '2019': 3.1881,
#   '2020': nan},
#  'crmw': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': 4.4896,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'crone': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': 0.6603,
#   '2019': nan,
#   '2020': nan},
#  'crowdre-ws': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'crownc': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': 1.7284,
#   '2007': 17.5299,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': 17.930990700000002,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'crowncom': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': 18.9826,
#   '2011': 0.6219,
#   '2012': 2.0011,
#   '2013': 17.930990700000002,
#   '2014': nan,
#   '2015': 0.2941,
#   '2016': 20.3042,
#   '2017': nan,
#   '2018': nan,
#   '2019': 8.8515,
#   '2020': nan},
#  'crss': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': 7.375,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'crv': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': 3.8845,
#   '2005': 3.616,
#   '2006': 3.339,
#   '2007': 3.0373,
#   '2008': 2.737,
#   '2009': 2.4696,
#   '2010': 2.5621,
#   '2011': 2.5066,
#   '2012': nan,
#   '2013': 2.5167,
#   '2014': nan,
#   '2015': 2.7555,
#   '2016': 3.0142,
#   '2017': 3.1081,
#   '2018': 3.1274,
#   '2019': 3.243,
#   '2020': 0.5068},
#  'crw': {'1995': nan,
#   '1996': nan,
#   '1997': nan,
#   '1998': nan,
#   '1999': nan,
#   '2000': nan,
#   '2001': nan,
#   '2002': nan,
#   '2003': nan,
#   '2004': nan,
#   '2005': nan,
#   '2006': nan,
#   '2007': nan,
#   '2008': nan,
#   '2009': nan,
#   '2010': nan,
#   '2011': nan,
#   '2012': nan,
#   '2013': nan,
#   '2014': nan,
#   '2015': nan,
#   '2016': nan,
#   '2017': nan,
#   '2018': nan,
#   '2019': nan,
#   '2020': nan},
#  'crypto': {'1995': 7.9732,
#   '1996': 8.2756,
#   '1997': 8.2525,
#   '1998': 7.4767,
#   '1999': 7.5796,
#   '2000': 7.8343,
#   '2001': 7.0975,
#   '2002': 6.4434,
#   '2003': 6.2082,
#   '2004': 6.7606,
#   '2005': 7.1484,
#   '2006': 18.3178,
#   '2007': 17.5299,
#   '2008': 17.5703,
#   '2009': 16.0508,
#   '2010': 16.2275,
#   '2011': 14.7271416,
#   '2012': 17.1629897,
#   '2013': 17.930990700000002,
#   '2014': 17.8311354,
#   '2015': 17.686452600000003,
#   '2016': 17.5261488,
#   '2017': 17.4291746,
#   '2018': 16.9324918,
#   '2019': 16.5478,
#   '2020': 4.5037},
#  ...}

# %%
# Creo un dictionary dove per ogni conferenza mi salvo anno e citazioni medie, dal 1995 al 2020

dict_avg_cit_conference = {}
for row,col in avg_cit_per_year.iloc[:,44:70].iterrows():
    x = {}
    for k,v in col.items():
        x[k] = v
    dict_avg_cit_conference[row] = x

# %% [markdown]
# Qui di seguito c'è il codice relativo ai grafici per riprodurre la fig.3 del paper.
# Ho provato ad inserirvi diverse decine di conferenze con i rispettivi TA: purtroppo non ho avuto risultati soddisfacenti; la linea delle citazioni ha un andamento molto diverso da quella dei TA, a volte persino opposto (ad un brusco calo delle citazioni corrisponde un netto aumento dei TA).

# %%
# fig,ax = plt.subplots(figsize=(8,6))
# sns.lineplot(x=list(dict_TA_conf_year['adhoc-now'].keys()), y=list(dict_TA_conf_year['adhoc-now'].values()),label='Tourist Arrivals')
# sns.lineplot(x=list(dict_avg_cit_conference['adhoc-now'].keys()), y=list(dict_avg_cit_conference['adhoc-now'].values()),label='Average Citations')
# sns.scatterplot(x=list(dict_TA_conf_year['adhoc-now'].keys()), y=list(dict_TA_conf_year['adhoc-now'].values()))
# sns.scatterplot(x=list(dict_avg_cit_conference['adhoc-now'].keys()), y=list(dict_avg_cit_conference['adhoc-now'].values()))
# #ax.set_xticklabels(ax.get_xticklabels(), rotation=75)
# plt.xticks(rotation=75)
# plt.tight_layout()
# #plt.savefig('charts/conf_tot_core_a.png')

# %% [markdown]
# ## Confronto tra citazioni medie  e altri indici turistici
# Verranno utilizzati tutti gli indici estratti dal report del World Economic Forum, per riprodurre la fig, 4 del paper.

# %%
# creo un dataframe con le citazioni medie per ogni stato, ed i relativi indici turistici
country_tot_cit = df_COCI.groupby(['Country']).CitationCount.sum().sort_values(ascending=False)
country_tot_articles = df_COCI.groupby(['Country']).CitationCount.count().sort_values(ascending=False)
country_avg_cit = {key:(int(val)/int(country_tot_articles[key])) for key,val in country_tot_cit.items()}
dict_cit_country_indexes = {k:[v,country_avg_cit[k]] for k,v in country_tot_cit.items()} 
df_country_avg_cit = pd.DataFrame(data=dict_cit_country_indexes.values(), index=dict_cit_country_indexes.keys(), columns=['TotCit', 'AvgCit'])

cit_country_indexes = df_country_avg_cit.join(touristic_indexes_countries.set_index('Country'))
# elimino le colonne che non servono
cit_country_indexes.drop(columns=[str(x) for x in list(range(1995,2021))], inplace=True)
cit_country_indexes
# Out:
#                 TotCit    AvgCit  TTCI   EE  TTPEC  INF  NCR   BE   SS   HH  \
# United States  7345210  7.468158   5.3  5.8    4.6  5.8  4.9  5.8  5.6  5.8
# China           886112  2.465744   4.9  5.2    4.3  3.9  6.1  4.7  5.6  5.6
# Canada          871060  6.094696   5.1  5.6    4.6  5.5  4.4  5.2  6.1  5.7
# Germany         636932  4.914826   5.4  6.0    4.8  5.5  5.3  5.4  5.8  7.0
# France          603906  5.242604   5.4  5.6    4.8  5.4  5.9  4.8  5.7  6.5
# ...                ...       ...   ...  ...    ...  ...  ...  ...  ...  ...
# Liechtenstein        4  0.173913   NaN  NaN    NaN  NaN  NaN  NaN  NaN  NaN
# Faroe Islands        4  0.108108   NaN  NaN    NaN  NaN  NaN  NaN  NaN  NaN
# Mauritius            1  0.050000   4.0  5.3    4.6  4.3  1.8  5.4  5.8  5.6
# Tanzania             0  0.000000   3.4  3.7    4.5  2.5  3.0  4.0  5.2  3.0
# Uzbekistan           0  0.000000   NaN  NaN    NaN  NaN  NaN  NaN  NaN  NaN
#
#                ...  ICTR  PTT   IO   PC   ES  ATI  GPI  TSI   NR  CRBT
# United States  ...   6.0  5.5  4.0  4.7  4.1  5.9  4.9  6.6  5.0   4.7
# China          ...   5.0  4.8  3.1  5.7  3.8  4.3  3.9  3.5  5.1   7.0
# Canada         ...   5.8  5.1  3.6  4.9  4.9  6.6  3.9  6.1  4.8   4.0
# Germany        ...   6.0  5.0  4.3  4.6  5.3  4.9  5.7  5.9  4.1   6.5
# France         ...   5.9  5.1  4.2  4.5  5.3  4.8  5.6  5.7  4.9   6.8
# ...            ...   ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# Liechtenstein  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# Faroe Islands  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# Mauritius      ...   4.9  6.1  3.6  4.6  4.3  3.2  4.6  5.0  2.4   1.3
# Tanzania       ...   2.9  4.9  3.3  5.5  4.4  2.2  2.8  2.4  4.7   1.3
# Uzbekistan     ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [126 rows x 21 columns]

# %%
_ = cit_country_indexes.copy()
_.rename({'TTCI':'metric'},axis=1,inplace=True)
_.loc[:,'KIND']='TTCI'

for x in cit_country_indexes.columns[2:]:
    __ = cit_country_indexes.copy()
    __.rename({str(x):'metric'},axis=1,inplace=True)
    __.loc[:,'KIND']= str(x)
    _ = _.append(__)
    
    
_['metric'] = _['metric'].round(decimals=1)
_.sort_values(['KIND'],inplace=True)

# %%
fig,ax = plt.subplots(5,4,figsize=(18,20))
i = j = 0
for index in cit_country_indexes.columns[2:]:
    sns.regplot(data=_[_['KIND']==str(index)],x='metric',y='AvgCit',order=1,ci=None,line_kws={'linewidth':5},label=str(index),ax=ax[i][j])
    sns.regplot(data=_[_['KIND']==str(index)],x='metric',y='AvgCit',order=1,line_kws={'linewidth':5},label=str(index),ax=ax[i][j])
    
    ax[i][j].set_xlabel(str(index))
    ax[i][j].set_ylabel('Average citations')
    ax[i][j].set_ylim(0,15)
    

    j+= 1
    if j == 4:
        j = 0
        i += 1

plt.tight_layout()
# plt.savefig('charts/cit_vs_metric_with_fit.png')

# %% [markdown]
# #### Commento
# Nella quasi totalità dei grafici di regressione lineare sopra riportati, notiamo un aumento delle citazioni medie all'aumentare del valore dell'indice che si trova sull'asse x.
# L'unica eccezione la fa l'indice PC, che descrive la competitività dei prezzi di uno Stato. Esso infatti segue un trend inverso rispetto a tutti gli altri indici

# %% [markdown]
# ## Correlazione indici turistici relativi ad uno Stato

# %%
_.drop(columns=['metric'],inplace=True)
corr_spearman = _.corr(method= 'spearman')
corr_kendall = _.corr(method= 'kendall')
corr_pearson = _.corr(method= 'pearson')

_s = corr_spearman.rename({'AvgCit':'Spearman'},axis=1)
_k = corr_kendall.rename({'AvgCit':'Kendall'},axis=1)
_p = corr_pearson.rename({'AvgCit':'Pearson'},axis=1)

_s.drop(['TotCit','AvgCit'], inplace=True)
_k.drop(['TotCit','AvgCit'], inplace=True)
_p.drop(['TotCit','AvgCit'], inplace=True)

fig,ax = plt.subplots(1,3,figsize=(8,7))
#plt.title('Citazioni medie', loc='left', fontsize = 15)
cmap = sns.diverging_palette(230, 15, as_cmap=True)

sns.heatmap(_s[['Spearman']],ax=ax[0],cmap=cmap,cbar=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_p[['Pearson']],ax=ax[1],cmap=cmap,cbar=False,yticklabels=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_k[['Kendall']],ax=ax[2],cmap=cmap,yticklabels=False,vmin=-1,vmax=1,annot=True)
# plt.savefig('charts/corr_avg_cit_country.png')

_s = corr_spearman.rename({'TotCit':'Spearman'},axis=1)
_k = corr_kendall.rename({'TotCit':'Kendall'},axis=1)
_p = corr_pearson.rename({'TotCit':'Pearson'},axis=1)

_s.drop(['TotCit','AvgCit'], inplace=True)
_k.drop(['TotCit','AvgCit'], inplace=True)
_p.drop(['TotCit','AvgCit'], inplace=True)

fig,ax = plt.subplots(1,3,figsize=(8,7))
#plt.title('Citazioni totali', loc='left', fontsize = 15)
sns.heatmap(_s[['Spearman']],ax=ax[0],cmap=cmap,cbar=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_p[['Pearson']],ax=ax[1],cmap=cmap,cbar=False,yticklabels=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_k[['Kendall']],ax=ax[2],cmap=cmap,yticklabels=False,vmin=-1,vmax=1,annot=True)
# plt.savefig('charts/corr_tot_cit_country.png')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Commenti
# Anche il calcolo della correlazione fa emergere il legame tra gli indici del World Economic Forum e le citazioni degli articoli. Stavolta non vengono analizzate solo le citazioni medie ma anche quelle totali.
# - Se nel grafico delle citazioni medie (prima riga) non notiamo particolari differenze tra le tre tipologie diverse di correlazione, nelle citazioni totali si può notare la correlazione di Pearson che riporta valori molto più bassi rispetto alle altre due.
# - La similitudine più grande tra citazioni medie e totali è sicuramente la correlazione negativa dell'indice PC: si rimane quindi coerenti con l'analisi dei grafici di regressione lineare sopra riportati.
# -Se osserviamo i valori degli indici presenti nel paper e li confrontiamo con i nuovi valori, anche qui notiamo delle somiglianze. Esempio:
# TTCI nel paper, citazioni medie:
# Pearson 0.57
# Spearman 0.5
# Kendall 0.42
# TTCI nei nuovi risultati, citazioni medie:
# Pearson 0.67
# Spearman 0.59
# Kendall 0.48

# %% [markdown]
# ## Correlazione indici turistici relativi alle città

# %%
# creo un dataframe con le citazioni medie e totali per ogni città, ed i relativi indici turistici

df_COCI['City'] = df_COCI['ConferenceLocation'].str.split(',').str[0]
city_tot_cit = df_COCI.groupby(['City']).CitationCount.sum().sort_values(ascending=False)
city_tot_articles = df_COCI.groupby(['City']).CitationCount.count().sort_values(ascending=False)
city_avg_cit = {key:(int(val)/int(city_tot_articles[key])) for key,val in city_tot_cit.items()}
dict_cit_city_indexes = {k:[v,city_avg_cit[k]] for k,v in city_tot_cit.items()} 
df_city_avg_cit = pd.DataFrame(data=dict_cit_city_indexes.values(), index=dict_cit_city_indexes.keys(), columns=['TotCit', 'AvgCit'])

touristic_indexes_cities = pd.read_csv('all_indexes_by_city.csv')
cit_city_indexes = df_city_avg_cit.join(touristic_indexes_cities.set_index('city'))
# i risultati di google erano salvati come stringa, quindi non riuscivo a fare il calcolo della correlazione. converto in intero
cit_city_indexes['google'] = cit_city_indexes['google'].str.replace('.','')
cit_city_indexes['google'] = pd.to_numeric(cit_city_indexes['google'])
cit_city_indexes
# Out:
# /tmp/ipykernel_2436/1278992291.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cit_city_indexes['google'] = cit_city_indexes['google'].str.replace('.','')
#                    TotCit    AvgCit      google  booking  tripadvisor
# San Diego          399660  6.719459   868000000  980.000        1.704
# San Francisco      381481  8.193848  1160000000  287.000        2.327
# Seattle            266898  8.531454   841000000  272.000        1.342
# Washington         257349  6.477937  1990000000  276.000        1.265
# Boston             238716  8.706543  1170000000  243.000        1.124
# ...                   ...       ...         ...      ...          ...
# Wangjing                0  0.000000     2800000   38.000        2.463
# Carmignano              0  0.000000     3020000   29.000       34.000
# Marabá                  0  0.000000    22900000   14.000       11.000
# Marbella                0  0.000000   108000000    2.643      450.000
# Indramayu Regency       0  0.000000     1960000      NaN        6.000
#
# [2403 rows x 5 columns]

# %%
corr_spearman = cit_city_indexes.corr(method= 'spearman')
corr_kendall = cit_city_indexes.corr(method= 'kendall')
corr_pearson = cit_city_indexes.corr(method= 'pearson')

_s = corr_spearman.rename({'AvgCit':'Spearman'},axis=1)
_k = corr_kendall.rename({'AvgCit':'Kendall'},axis=1)
_p = corr_pearson.rename({'AvgCit':'Pearson'},axis=1)

_s.drop(['TotCit','AvgCit'], inplace=True)
_k.drop(['TotCit','AvgCit'], inplace=True)
_p.drop(['TotCit','AvgCit'], inplace=True)

fig,ax = plt.subplots(1,3,figsize=(8,7))
#plt.title('Citazioni medie', loc='left', fontsize = 15)
cmap = sns.diverging_palette(230, 15, as_cmap=True)

sns.heatmap(_s[['Spearman']],ax=ax[0],cmap=cmap,cbar=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_p[['Pearson']],ax=ax[1],cmap=cmap,cbar=False,yticklabels=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_k[['Kendall']],ax=ax[2],cmap=cmap,yticklabels=False,vmin=-1,vmax=1,annot=True)
# plt.savefig('charts/corr_avg_cit_city.png')

_s = corr_spearman.rename({'TotCit':'Spearman'},axis=1)
_k = corr_kendall.rename({'TotCit':'Kendall'},axis=1)
_p = corr_pearson.rename({'TotCit':'Pearson'},axis=1)

_s.drop(['TotCit','AvgCit'], inplace=True)
_k.drop(['TotCit','AvgCit'], inplace=True)
_p.drop(['TotCit','AvgCit'], inplace=True)

fig,ax = plt.subplots(1,3,figsize=(8,7))
#plt.title('Citazioni totali', loc='left', fontsize = 15)
sns.heatmap(_s[['Spearman']],ax=ax[0],cmap=cmap,cbar=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_p[['Pearson']],ax=ax[1],cmap=cmap,cbar=False,yticklabels=False,vmin=-1,vmax=1,annot=True)
sns.heatmap(_k[['Kendall']],ax=ax[2],cmap=cmap,yticklabels=False,vmin=-1,vmax=1,annot=True)
# plt.savefig('charts/corr_tot_cit_city.png')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Commenti
# - I risultati di quest'ultima analisi non sono molto incoraggianti: per quanto riguarda le citazioni medie, quasi tutti i valori sono vicini allo 0; ne abbiamo persino uno negativo, anche se comunque vicinissimo allo 0 (-0.005).
# -Un leggero miglioramento possiamo osservarlo nello schema delle citazioni totali (secondo schema): nello specifico i valori della correlazione con i risultati Google sono quelli che dimostrano un maggior nesso tra questo indice e le citazioni.
# -Anche qui la correlazione di Pearson è la più "debole" tra tutte
